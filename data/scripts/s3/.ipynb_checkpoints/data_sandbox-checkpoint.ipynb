# %%
import json
import os
import glob

manifest = "output.manifest"
with open(manifest) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content]
json_items = []
for c in content:
    if c == "":
        continue
    obj = json.loads(c)
    json_items.append(obj)

# %%
prelabeled = []
ilabeled = []
for item in json_items:
    if 'NOAAlabelstodo' in item:
        del item['NOAAlabelstodo']
        ilabeled.append(item)        
    else:
        prelabeled.append(item)

# %% [markdown]
# ### Create 2016CHESS_US and 2019PB dataframes

# %%
import pandas as pd
annotations_path_chess = "/data/raw_data/PolarBears/2016CHESS_PolarBearAnnotations.csv"
annotations_path_2019 = "/data/raw_data/PolarBears/2019_pb_annotations.csv"
numeric_cols = ["Xmin", "Ymin", "Xmax", "Ymax"]
data2016 = pd.read_csv(annotations_path_chess, sep = ',', header=0, dtype={'PB_ID': object})
data2019 = pd.read_csv(annotations_path_2019, sep = ',', header=0, dtype={'PB_ID': object})
data2016[numeric_cols] =  data2016[numeric_cols].apply(pd.to_numeric)
data2019[numeric_cols] =  data2019[numeric_cols].apply(pd.to_numeric)
data2016 = data2016[data2016["Frame_color"].notnull()]
data2019 = data2019[data2019["Frame_xml"].notnull()]

# %% [markdown]
# ### Create 2016CHESS_RU

# %%
import xml.etree.ElementTree as ET

RU_PATH = "/data/raw_data/PolarBears/s3_images/2016_Chukchi_CHESS_Russia"
src=ilabeled[0]['source-ref']
category, file = src.replace("s3://","").split("/")[2:]
file_base = file.split(".")[0]
xml_files = glob.glob(os.path.join(RU_PATH, "*.xml"))
for f in xml_files:
    tree = ET.parse(f)
    root = tree.getroot()
    img = root[1].text
    PB_IDs = []
    xmins = []
    ymins = []
    xmaxs = []
    ymaxs = []
    for annotation in root[6:]:
        PB_IDS.append(annotation[0].text)
        xmin = annotation[4][0].text
        ymin = annotation[4][1].text
        xmax = annotation[4][2].text
        ymax = root[6][4][3].text
        print(img,PB_ID,xmin,ymin,xmax,ymax)
# Out:
# CHESS_ru_2016-04-18 13-25-42_1683_R.JPG PB201 3747 3446 3812 3493
# CHESS_ru_2016-04-25 10-59-14_2512_L.JPG PB202 404 578 443 634
# CHESS_ru_2016-04-25 10-59-14_2512_L.JPG PB203 414 565 450 634
# CHESS_ru_2016-04-25 13-59-33_1412_R.JPG PB206 6258 3797 6314 3854
# CHESS_ru_2016-04-26 11-24-29_0142_1L.JPG PB213 2155 4182 2261 4264
# CHESS_ru_2016-04-25 14-21-36_0652_L.JPG PB209 3201 2985 3250 3055
# CHESS_ru_2016-04-25 14-21-36_0652_L.JPG PB210 3188 2961 3240 3055
# CHESS_ru_2016-04-25 14-21-36_0652_L.JPG PB210s 3188 2911 3242 3055
# CHESS_ru_2016-04-25 14-21-36_0652_L.JPG PB211 3178 2863 3240 3055
# CHESS_ru_2016-04-25 14-21-36_0652_L.JPG PB211s 3178 2817 3240 3055
# CHESS_ru_2016-04-25 11-06-03_2568_L.JPG PB204 230 1258 287 1311
# CHESS_ru_2016-04-18 13-25-41_1682_R.JPG PB201 3805 1279 3860 1329
# CHESS_ru_2016-04-25 15-08-38_2037_R.JPG PB212 4781 4433 4874 4500
# CHESS_ru_2016-04-25 13-59-31_1410_R.JPG PB206 6129 551 6182 602
# CHESS_ru_2016-04-25 13-59-32_1411_R.JPG PB206 6166 1565 6214 1622
# CHESS_ru_2016-04-25 14-09-54_2051_r_C.JPG PB207 5800 2949 5848 3028
# CHESS_ru_2016-04-25 14-09-54_2051_r_C.JPG PB208 5792 2969 5832 3028
# CHESS_ru_2016-05-12 11-30-06_0101_2R.JPG PB215 5058 686 5113 728
# CHESS_ru_2016-04-26 13-04-55_1101_r_3C.JPG PB214 2172 4314 2282 4405
# CHESS_ru_2016-04-26 13-04-55_1101_r_3C.JPG PB214s 2171 4313 2287 4405
# CHESS_ru_2016-04-25 11-06-04_2569_L.JPG PB204 141 3166 204 3212
# CHESS_ru_2016-04-25 11-06-04_2569_L.JPG PB204s 140 3147 204 3212
# CHESS_ru_2016-04-25 13-50-46_1257_R.JPG PB205 6491 656 6538 714
# CHESS_ru_2016-04-25 13-50-46_1257_R.JPG PB205s 6475 657 6538 714
# {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-04-18 13-25-41_1682_R.JPG',
#  'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#     'width': 52,
#     'top': 1280,
#     'height': 48,
#     'left': 3805}],
#   'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#  'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/ffff',
#   'class-map': {'0': 'Polar Bear'},
#   'human-annotated': 'yes',
#   'objects': [{'confidence': 0.09}],
#   'creation-date': '2019-08-02T03:31:09.516627',
#   'type': 'groundtruth/object-detection'}}

# %%
for obj in prelabeled:
    src = obj["source-ref"]
    category, file = src.replace("s3://","").split("/")[2:]
    if category == "2019_Beaufort_PolarBears":
        row2 = data2019[data2019["Frame_xml"].str.contains(file[:10])]
    elif category == "2016_Chukchi_CHESS_Russia":
        print("?")
    elif category == "2016_Chukchi_CHESS_US":
        row2 = data2016[data2016["Frame_color"].str.contains(file[:-4])]
    widths = list(row2['Xmax']-row2['Xmin'])
    heights = list(row2['Ymax']-row2['Ymin'])
    ids = list(row2['PB_ID'])
    ages = list(row2['Age_class'])
    badres = True in list(row2['Poor_image_quality'].notnull())
    
    for i, det in enumerate(obj['NOAAlabelsdone']['annotations']):
        for j in range(len(ids)):
            h = det['height']
            w = det['width']
            if heights[j] == h and widths[j] == w:
                obj['NOAAlabelsdone']['annotations'][i]['PB_ID'] = ids[j]
                obj['NOAAlabelsdone']['annotations'][i]['Age_class'] = ages[j]
    obj['NOAAlabelsdone-metadata']['job-name'] = "labeling-job/done-by-noaa"
    obj['NOAAlabelsdone-metadata']['bad-res'] = badres
for obj in ilabeled:
    obj['NOAAlabelsdone-metadata']['job-name'] = "labeling-job/done-by-me"

# %%
combined = prelabeled + ilabeled
for row in combined:
    with open("updated.manifest", "a") as f:
        json.dump(row, f, sort_keys=True)
        f.write("\r\n")

# %%
# Out:
# [{'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 83.0,
#      'left': 5268.5,
#      'top': 2703.5,
#      'width': 139.0,
#      'PB_ID': 'PB001',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL12_C_160422_001727.393_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 134.0,
#      'left': 4150.0,
#      'top': 379.0,
#      'width': 60.0,
#      'PB_ID': 'PB001',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL12_S_160422_002008.487_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 49.0,
#      'left': 3997.0,
#      'top': 898.5,
#      'width': 26.0,
#      'PB_ID': 'PB002',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 54.0,
#      'left': 4000.5,
#      'top': 901.0,
#      'width': 33.0,
#      'PB_ID': 'PB002s',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL19_S_160510_221428.054_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 54.0,
#      'left': 4449.5,
#      'top': 1202.0,
#      'width': 53.0,
#      'PB_ID': 'PB003',
#      'Age_class': 'cub'},
#     {'class_id': 0,
#      'height': 41.0,
#      'left': 4436.5,
#      'top': 1180.5,
#      'width': 59.0,
#      'PB_ID': 'PB004',
#      'Age_class': 'cub'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL20_C_160511_234351.795_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 81.0,
#      'left': 2279.0,
#      'top': 899.5,
#      'width': 56.0,
#      'PB_ID': 'PB005',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 93.0,
#      'left': 2268.5,
#      'top': 904.5,
#      'width': 79.0,
#      'PB_ID': 'PB005s',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL20_P_160511_233901.340_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL20_P_160511_233902.495_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL20_P_160511_234136.442_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 72.0,
#      'left': 3208.0,
#      'top': 2697.0,
#      'width': 106.0,
#      'PB_ID': 'PB005',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL20_P_160511_234137.209_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 107.0,
#      'left': 657.0,
#      'top': 1932.5,
#      'width': 98.0,
#      'PB_ID': 'PB006',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL22_C_160517_001218.856_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 292.0,
#      'left': 2614.0,
#      'top': 3899.0,
#      'width': 174.0,
#      'PB_ID': 'PB008',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 568.0,
#      'left': 2600.5,
#      'top': 3761.0,
#      'width': 205.0,
#      'PB_ID': 'PB008s',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL27_C_160530_012411.163_COLOR-8-BIT_08.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 132.0,
#      'left': 348.0,
#      'top': 2668.0,
#      'width': 256.0,
#      'PB_ID': 'PB014',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 402.0,
#      'left': 348.5,
#      'top': 2532.0,
#      'width': 259.0,
#      'PB_ID': 'PB014s',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL27_C_160530_012418.586_COLOR-8-BIT_09.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 165.0,
#      'left': 3856.5,
#      'top': 2908.5,
#      'width': 259.0,
#      'PB_ID': 'PB011',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL27_S_160530_012051.009_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 151.0,
#      'left': 147.5,
#      'top': 3519.5,
#      'width': 71.0,
#      'PB_ID': 'PB019',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 266.0,
#      'left': 138.0,
#      'top': 3462.0,
#      'width': 104.0,
#      'PB_ID': 'PB019s',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL6_P_160413_204106.093_COLOR-8-BIT.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 114,
#      'left': 3350.0,
#      'top': 2052.0,
#      'width': 70,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 142,
#      'left': 3351.0,
#      'top': 2038.0,
#      'width': 72,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 50,
#      'left': 3307.5,
#      'top': 2320.0,
#      'width': 91,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/001_polar_bear_2019_fl10_R_20190516_213647.307061_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 97,
#      'left': 3423.5,
#      'top': 4057.5,
#      'width': 51,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 152,
#      'left': 3426.0,
#      'top': 4031.0,
#      'width': 56,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 72,
#      'left': 3357.5,
#      'top': 4311.0,
#      'width': 55,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/002_polar_bear_2019_fl10_R_20190516_213647.709101_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 113,
#      'left': 3340.0,
#      'top': 722.5,
#      'width': 70,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 116,
#      'left': 3331.0,
#      'top': 722.0,
#      'width': 88,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 75,
#      'left': 3394.0,
#      'top': 883.5,
#      'width': 52,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 89,
#      'left': 3382.5,
#      'top': 891.5,
#      'width': 77,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/003_polar_bear_2019_fl10_C_20190516_213908.735676_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 104,
#      'left': 3352.5,
#      'top': 2815.0,
#      'width': 59,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 125,
#      'left': 3325.5,
#      'top': 2824.5,
#      'width': 117,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 99,
#      'left': 3403.0,
#      'top': 3028.5,
#      'width': 54,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 107,
#      'left': 3389.0,
#      'top': 3030.5,
#      'width': 80,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/004_polar_bear_2019_fl10_C_20190516_213909.424159_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 54,
#      'left': 5888.0,
#      'top': 1601.0,
#      'width': 104,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 76,
#      'left': 5873.0,
#      'top': 1612.0,
#      'width': 136,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 63,
#      'left': 5874.5,
#      'top': 1653.5,
#      'width': 83,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 83,
#      'left': 5858.0,
#      'top': 1664.5,
#      'width': 118,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/005_polar_bear_2019_fl10_L_20190516_214038.871274_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 67,
#      'left': 6412.5,
#      'top': 3726.5,
#      'width': 103,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 84,
#      'left': 6397.5,
#      'top': 3734.0,
#      'width': 137,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 74,
#      'left': 6396.0,
#      'top': 3777.0,
#      'width': 82,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 73,
#      'left': 6384.0,
#      'top': 3777.5,
#      'width': 108,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/006_polar_bear_2019_fl10_L_20190516_214039.647498_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 102,
#      'left': 4153.0,
#      'top': 493.0,
#      'width': 72,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 121,
#      'left': 4143.5,
#      'top': 501.5,
#      'width': 91,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 88,
#      'left': 4098.0,
#      'top': 636.0,
#      'width': 60,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 105,
#      'left': 4089.5,
#      'top': 643.5,
#      'width': 79,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/007_polar_bear_2019_fl10_L_20190516_214201.256925_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 82,
#      'left': 3918.5,
#      'top': 2320.0,
#      'width': 85,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 101,
#      'left': 3909.5,
#      'top': 2329.5,
#      'width': 107,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 99,
#      'left': 3854.0,
#      'top': 2442.5,
#      'width': 54,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 107,
#      'left': 3848.5,
#      'top': 2444.5,
#      'width': 69,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/008_polar_bear_2019_fl10_L_20190516_214202.006311_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 73,
#      'left': 3693.5,
#      'top': 4174.5,
#      'width': 77,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 88,
#      'left': 3682.5,
#      'top': 4182.0,
#      'width': 101,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 94,
#      'left': 3632.0,
#      'top': 4248.0,
#      'width': 50,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 104,
#      'left': 3623.5,
#      'top': 4254.0,
#      'width': 67,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/009_polar_bear_2019_fl10_L_20190516_214202.761314_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 51,
#      'left': 195.0,
#      'top': 2697.5,
#      'width': 122,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 61,
#      'left': 167.5,
#      'top': 2701.5,
#      'width': 175,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/010_polar_bear_2019_fl10_R_20190516_214404.532608_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 125,
#      'left': 3265.0,
#      'top': 1307.5,
#      'width': 60,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 124,
#      'left': 3249.0,
#      'top': 1307.0,
#      'width': 92,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 102,
#      'left': 3228.0,
#      'top': 1391.0,
#      'width': 44,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 106,
#      'left': 3211.5,
#      'top': 1393.0,
#      'width': 81,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/011_polar_bear_2019_fl10_C_20190516_214815.238825_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 110,
#      'left': 3027.0,
#      'top': 3413.0,
#      'width': 74,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 116,
#      'left': 3011.0,
#      'top': 3415.0,
#      'width': 110,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 123,
#      'left': 2981.5,
#      'top': 3500.5,
#      'width': 47,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 125,
#      'left': 2965.0,
#      'top': 3500.5,
#      'width': 84,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/012_polar_bear_2019_fl10_C_20190516_214816.197468_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 130,
#      'left': 1471.0,
#      'top': 1761.0,
#      'width': 72,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 133,
#      'left': 1459.5,
#      'top': 1761.5,
#      'width': 95,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 100,
#      'left': 1499.5,
#      'top': 1605.0,
#      'width': 51,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 100,
#      'left': 1484.0,
#      'top': 1605.0,
#      'width': 84,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/013_polar_bear_2019_fl10_C_20190516_215224.805373_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 117,
#      'left': 1505.5,
#      'top': 3958.5,
#      'width': 65,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 125,
#      'left': 1490.5,
#      'top': 3960.5,
#      'width': 97,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 93,
#      'left': 1496.5,
#      'top': 3799.5,
#      'width': 63,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 99,
#      'left': 1478.0,
#      'top': 3801.5,
#      'width': 102,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/014_polar_bear_2019_fl10_C_20190516_215225.666433_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 133,
#      'left': 128.0,
#      'top': 3373.5,
#      'width': 158,
#      'PB_ID': 'PB101orPB102',
#      'Age_class': 'adult or yearling'},
#     {'class_id': 0,
#      'height': 160,
#      'left': 111.5,
#      'top': 3385.0,
#      'width': 195,
#      'PB_ID': 'PB101orPB102s',
#      'Age_class': 'adult or yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/015_polar_bear_2019_fl10_R_20190516_215358.348631_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 66,
#      'left': 6544.5,
#      'top': 3118.0,
#      'width': 63,
#      'PB_ID': 'PB101orPB102',
#      'Age_class': 'adult or yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/016_polar_bear_2019_fl10_L_20190516_215512.736147_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 135,
#      'left': 221.5,
#      'top': 3279.5,
#      'width': 77,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 145,
#      'left': 200.5,
#      'top': 3274.5,
#      'width': 121,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 83,
#      'left': 233.5,
#      'top': 3370.5,
#      'width': 83,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 84,
#      'left': 214.0,
#      'top': 3371.0,
#      'width': 120,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/017_polar_bear_2019_fl10_R_20190516_215617.263662_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 39,
#      'left': 6552.5,
#      'top': 1500.5,
#      'width': 47,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 103,
#      'left': 6542.0,
#      'top': 1533.5,
#      'width': 68,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 70,
#      'left': 6498.0,
#      'top': 1690.0,
#      'width': 106,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 98,
#      'left': 6489.5,
#      'top': 1704.0,
#      'width': 127,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/018_polar_bear_2019_fl10_L_20190516_215722.489378_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 95,
#      'left': 5332.5,
#      'top': 3446.5,
#      'width': 129,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 116,
#      'left': 5323.5,
#      'top': 3457.0,
#      'width': 145,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 75,
#      'left': 5230.0,
#      'top': 3609.5,
#      'width': 108,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 97,
#      'left': 5223.0,
#      'top': 3620.5,
#      'width': 122,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/019_polar_bear_2019_fl10_L_20190516_215723.149742_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 67,
#      'left': 2126.0,
#      'top': 1339.5,
#      'width': 96,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 66,
#      'left': 2103.0,
#      'top': 1340.0,
#      'width': 146,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 45,
#      'left': 2582.5,
#      'top': 1606.5,
#      'width': 97,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 55,
#      'left': 2560.0,
#      'top': 1603.5,
#      'width': 148,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/020_polar_bear_2019_fl10_C_20190516_215840.109380_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 73,
#      'left': 2184.0,
#      'top': 3312.5,
#      'width': 102,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 72,
#      'left': 2158.0,
#      'top': 3313.0,
#      'width': 152,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 64,
#      'left': 2595.0,
#      'top': 3566.0,
#      'width': 104,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 73,
#      'left': 2578.0,
#      'top': 3561.5,
#      'width': 138,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/021_polar_bear_2019_fl10_C_20190516_215840.925365_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 67,
#      'left': 3446.0,
#      'top': 130.5,
#      'width': 124,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 106,
#      'left': 3445.5,
#      'top': 149.0,
#      'width': 125,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/022_polar_bear_2019_fl10_L_20190516_215949.199814_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 58,
#      'left': 2628.5,
#      'top': 1824.0,
#      'width': 133,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 101,
#      'left': 2628.0,
#      'top': 1844.5,
#      'width': 132,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 59,
#      'left': 2956.0,
#      'top': 1405.5,
#      'width': 92,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 102,
#      'left': 2955.5,
#      'top': 1427.0,
#      'width': 93,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/023_polar_bear_2019_fl10_L_20190516_215949.807474_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 66,
#      'left': 2139.0,
#      'top': 3469.0,
#      'width': 122,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 101,
#      'left': 2138.0,
#      'top': 3486.5,
#      'width': 120,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 65,
#      'left': 2474.0,
#      'top': 3091.5,
#      'width': 78,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 106,
#      'left': 2474.5,
#      'top': 3111.0,
#      'width': 79,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/024_polar_bear_2019_fl10_L_20190516_215950.415116_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 102,
#      'left': 3328.0,
#      'top': 52.0,
#      'width': 52,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 102,
#      'left': 3306.5,
#      'top': 53.0,
#      'width': 97,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/025_polar_bear_2019_fl10_C_20190516_220114.862286_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 138,
#      'left': 3573.0,
#      'top': 1905.0,
#      'width': 54,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 153,
#      'left': 3552.5,
#      'top': 1898.5,
#      'width': 97,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 121,
#      'left': 3566.5,
#      'top': 2065.5,
#      'width': 49,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 133,
#      'left': 3546.5,
#      'top': 2060.5,
#      'width': 91,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/026_polar_bear_2019_fl10_C_20190516_220116.307030_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 128,
#      'left': 3905.5,
#      'top': 4054.0,
#      'width': 57,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 147,
#      'left': 3884.5,
#      'top': 4044.5,
#      'width': 101,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 106,
#      'left': 3895.5,
#      'top': 4213.0,
#      'width': 47,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 117,
#      'left': 3875.0,
#      'top': 4208.5,
#      'width': 86,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/027_polar_bear_2019_fl10_C_20190516_220117.031913_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 74,
#      'left': 2468.0,
#      'top': 1160.0,
#      'width': 80,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 126,
#      'left': 2457.0,
#      'top': 1187.0,
#      'width': 102,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 46,
#      'left': 2521.0,
#      'top': 1146.0,
#      'width': 80,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 97,
#      'left': 2511.0,
#      'top': 1171.5,
#      'width': 100,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/028_polar_bear_2019_fl10_C_20190516_220227.617607_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 72,
#      'left': 1815.0,
#      'top': 3230.0,
#      'width': 88,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 106,
#      'left': 1807.0,
#      'top': 3246.0,
#      'width': 106,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 58,
#      'left': 1875.5,
#      'top': 3214.0,
#      'width': 75,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 92,
#      'left': 1872.5,
#      'top': 3231.0,
#      'width': 85,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/029_polar_bear_2019_fl10_C_20190516_220228.490410_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 66,
#      'left': 3981.0,
#      'top': 1216.0,
#      'width': 66,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 61,
#      'left': 3729.5,
#      'top': 1415.5,
#      'width': 61,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/030_polar_bear_2019_fl10_R_20190516_220346.007612_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 100,
#      'left': 4543.0,
#      'top': 2996.0,
#      'width': 76,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 79,
#      'left': 4308.0,
#      'top': 3206.5,
#      'width': 74,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': True},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/031_polar_bear_2019_fl10_R_20190516_220346.626755_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 45,
#      'left': 2834.5,
#      'top': 23.5,
#      'width': 97,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 88,
#      'left': 2837.0,
#      'top': 45.0,
#      'width': 104,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/032_polar_bear_2019_fl10_L_20190516_220440.007927_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 59,
#      'left': 1950.0,
#      'top': 1673.5,
#      'width': 110,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 95,
#      'left': 1950.0,
#      'top': 1690.5,
#      'width': 110,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 43,
#      'left': 1981.5,
#      'top': 1750.5,
#      'width': 97,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 81,
#      'left': 1984.5,
#      'top': 1768.5,
#      'width': 103,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/033_polar_bear_2019_fl10_L_20190516_220440.533428_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 62,
#      'left': 1370.5,
#      'top': 3375.0,
#      'width': 109,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 82,
#      'left': 1374.5,
#      'top': 3385.0,
#      'width': 117,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 48,
#      'left': 1405.0,
#      'top': 3451.0,
#      'width': 104,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 84,
#      'left': 1404.5,
#      'top': 3469.0,
#      'width': 103,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/034_polar_bear_2019_fl10_L_20190516_220441.064367_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 119,
#      'left': 1138.5,
#      'top': 3427.5,
#      'width': 53,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 138,
#      'left': 1155.0,
#      'top': 3437.0,
#      'width': 84,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 74,
#      'left': 1110.0,
#      'top': 3415.0,
#      'width': 52,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/035_polar_bear_2019_fl10_C_20190516_220652.430599_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 67,
#      'left': 4411.5,
#      'top': 34.5,
#      'width': 49,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 66,
#      'left': 4390.5,
#      'top': 34.0,
#      'width': 89,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 100,
#      'left': 4417.0,
#      'top': 264.0,
#      'width': 44,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 101,
#      'left': 4397.0,
#      'top': 263.5,
#      'width': 80,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
#   'source-ref': 's3://arcticseals/polarbears/2019_Beaufort_PolarBears/036_polar_bear_2019_fl10_C_20190516_220858.285032_rgb.JPG'},
#  {'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'height': 111,
#      'left': 5236.5,
#      'top': 2185.5,
#      'width': 51,
#      'PB_ID': 'PB101',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 127,
#      'left': 5205.0,
#      'top': 2176.5,
#      'width': 116,
#      'PB_ID': 'PB101s',
#      'Age_class': 'adult'},
#     {'class_id': 0,
#      'height': 92,
#      'left': 5246.5,
#      'top': 2432.0,
#      'width': 41,
#      'PB_ID': 'PB102',
#      'Age_class': 'yearling'},
#     {'class_id': 0,
#      'height': 101,
#      'left': 5227.5,
#      'top': 2427.5,
#      'width': 79,
#      'PB_ID': 'PB102s',
#      'Age_class': 'yearling'}],
#    'image_size': [{'depth': '3', 'height': '4384', 'width': '6576'}]},
#   'NOAAlabelsdone-metadata': {'class-map': {'0': 'Polar Bear'},
#    'creation-date': '2019-08-01T04:25:44.859597',
#    'human-annotated': 'yes',
#    'job-name': 'labeling-job/done-by-noaa',
#    'objects': [{'confidence': 1}],
#    'type': 'groundtruth/object-detection',
#    'bad-res': False},
# ...
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 32,
#      'top': 4215,
#      'height': 25,
#      'left': 5056},
#     {'class_id': 0, 'width': 40, 'top': 4229, 'height': 22, 'left': 5038}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}, {'confidence': 0.09}],
#    'creation-date': '2019-08-01T22:34:29.644666',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 11-30-16_1160_r_3C.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 33,
#      'top': 2256,
#      'height': 36,
#      'left': 519},
#     {'class_id': 0, 'width': 30, 'top': 2245, 'height': 41, 'left': 498},
#     {'class_id': 0, 'width': 66, 'top': 2159, 'height': 74, 'left': 562}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09},
#     {'confidence': 0.09},
#     {'confidence': 0.09}],
#    'creation-date': '2019-08-02T04:01:13.651675',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 11-44-33_0337_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 50,
#      'top': 874,
#      'height': 44,
#      'left': 4334}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:59:06.966146',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 11-44-33_0338_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 46,
#      'top': 3134,
#      'height': 52,
#      'left': 4154}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-01T22:36:42.502128',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 12-24-40_0910_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 126,
#      'top': 1564,
#      'height': 88,
#      'left': 5298}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:40:58.921401',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 13-35-04_2618_1L.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 72,
#      'top': 1475,
#      'height': 91,
#      'left': 1440}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-01T22:37:51.546912',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 14-20-10_2145_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 32,
#      'top': 1676,
#      'height': 44,
#      'left': 872},
#     {'class_id': 0, 'width': 63, 'top': 1362, 'height': 80, 'left': 915}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}, {'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:56:59.286000',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 14-20-11_2146_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 21,
#      'top': 4263,
#      'height': 40,
#      'left': 829},
#     {'class_id': 0, 'width': 69, 'top': 3975, 'height': 58, 'left': 859}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}, {'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:40:58.826860',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 14-38-06_2372_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 38,
#      'top': 132,
#      'height': 50,
#      'left': 5986}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-01T22:37:51.433257',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 14-38-07_2373_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 43,
#      'top': 2040,
#      'height': 23,
#      'left': 5984}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:39:52.306541',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-12 14-38-08_2374_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 33,
#      'top': 3902,
#      'height': 24,
#      'left': 5956},
#     {'class_id': 0, 'width': 21, 'top': 3903, 'height': 16, 'left': 5931},
#     {'class_id': 0, 'width': 18, 'top': 3918, 'height': 17, 'left': 5911}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09},
#     {'confidence': 0.09},
#     {'confidence': 0.09}],
#    'creation-date': '2019-08-01T22:39:00.049171',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-13 10-16-56_0023_1L.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 32,
#      'top': 890,
#      'height': 55,
#      'left': 1493}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:33:20.605133',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-13 10-16-57_0024_1L.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 34,
#      'top': 3882,
#      'height': 47,
#      'left': 1533}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:33:20.747936',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-13 11-33-21_0855_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 41,
#      'top': 4712,
#      'height': 36,
#      'left': 6139}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-01T22:36:42.612410',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-13 12-14-24_1226_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 80,
#      'top': 3887,
#      'height': 67,
#      'left': 375}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-01T22:37:51.683987',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-13 15-06-07_2768_1L.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 39,
#      'top': 1162,
#      'height': 60,
#      'left': 1265}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:27:51.640198',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-13 15-06-08_2769_1L.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 45,
#      'top': 3810,
#      'height': 26,
#      'left': 1184}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:59:06.857514',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-18 11-43-50_1486_1L.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 77,
#      'top': 4237,
#      'height': 39,
#      'left': 2493}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:51:30.737521',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-18 12-24-54_3956_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 61,
#      'top': 2937,
#      'height': 42,
#      'left': 2988}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:54:49.468701',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-18 12-34-25_2003_r_3C.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 63,
#      'top': 3547,
#      'height': 80,
#      'left': 4945}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-01T22:38:59.912591',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-18 12-39-15_2042_r_3C.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 38,
#      'top': 4097,
#      'height': 67,
#      'left': 3766},
#     {'class_id': 0, 'width': 34, 'top': 4165, 'height': 67, 'left': 3750},
#     {'class_id': 0, 'width': 40, 'top': 4236, 'height': 59, 'left': 3768}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09},
#     {'confidence': 0.09},
#     {'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:36:39.803890',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-18 12-51-06_4215_2R.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 45,
#      'top': 4026,
#      'height': 39,
#      'left': 6670}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:28:57.980952',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_Russia/CHESS_ru_2016-05-18 13-40-17_2481_r_3C.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 36,
#      'top': 3232,
#      'height': 98,
#      'left': 3929}],
#    'image_size': [{'width': 7360, 'depth': 3, 'height': 4912}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:54:49.348223',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS2016_N94S_FL8_P__20160415231242.791GMT_COLOR-8-BIT.JPG',
#   'NOAAlabelsdone': {'annotations': [{'class_id': 0,
#      'width': 148,
#      'top': 1338,
#      'height': 114,
#      'left': 6315}],
#    'image_size': [{'width': 6576, 'depth': 3, 'height': 4384}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {'0': 'Polar Bear'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-08-02T03:31:09.635143',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL20_C_160511_234538.500_COLOR-8-BIT.JPG',
#   'NOAAlabelsdone': {'annotations': [],
#    'image_size': [{'width': 6576, 'depth': 3, 'height': 4384}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {},
#    'human-annotated': 'yes',
#    'objects': [],
#    'creation-date': '2019-08-02T04:11:39.159897',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL29_C_160601_004437.203_COLOR-8-BIT.JPG',
#   'NOAAlabelsdone': {'annotations': [],
#    'image_size': [{'width': 6576, 'depth': 3, 'height': 4384}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {},
#    'human-annotated': 'yes',
#    'objects': [],
#    'creation-date': '2019-08-02T04:10:34.714805',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://arcticseals/polarbears/2016_Chukchi_CHESS_US/CHESS_FL8_C_160415_234345.641_COLOR-8-BIT.JPG',
#   'NOAAlabelsdone': {'annotations': [],
#    'image_size': [{'width': 6576, 'depth': 3, 'height': 4384}]},
#   'NOAAlabelsdone-metadata': {'job-name': 'labeling-job/done-by-me',
#    'class-map': {},
#    'human-annotated': 'yes',
#    'objects': [],
#    'creation-date': '2019-08-02T04:10:34.561918',
#    'type': 'groundtruth/object-detection'}}]
